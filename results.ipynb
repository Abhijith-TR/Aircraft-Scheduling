# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from scipy.interpolate import make_interp_spline, BSpline
import numpy as np

def make_smooth_plot(x, y, xlabel, ylabel, title, k_val=9):    
    spl = make_interp_spline(x, y, k=3)
    x_smooth = np.linspace(min(x), max(x), 200)
    y_smooth = spl(x_smooth)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.plot(x_smooth, y_smooth)
    plt.show()

def make_two_smooth_plots(x1, y1, x2, y2, label1, label2, xlabel, ylabel, title):
    spl1 = make_interp_spline(x1, y1, k=5)
    x_smooth1 = np.linspace(min(x1), max(x1), 200)
    y_smooth1 = spl1(x_smooth1)
    spl2 = make_interp_spline(x2, y2, k=5)
    x_smooth2 = np.linspace(min(x2), max(x2), 200)
    y_smooth2 = spl2(x_smooth2)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.plot(x_smooth1, y_smooth1, label=label1)
    plt.plot(x_smooth2, y_smooth2, label=label2)
    plt.legend()
    plt.show()

# %%
from scipy.interpolate import make_interp_spline, BSpline
import numpy as np

def make_smooth_plot(x, y, xlabel, ylabel, title, k_val=9):    
    spl = make_interp_spline(x, y, k=3)
    x_smooth = np.linspace(min(x), max(x), 200)
    y_smooth = spl(x_smooth)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.plot(x_smooth, y_smooth)
    plt.show()

def make_two_smooth_plots(x1, y1, x2, y2, label1, label2, xlabel, ylabel, title):
    spl1 = make_interp_spline(x1, y1, k=5)
    x_smooth1 = np.linspace(min(x1), max(x1), 200)
    y_smooth1 = spl1(x_smooth1)
    spl2 = make_interp_spline(x2, y2, k=5)
    x_smooth2 = np.linspace(min(x2), max(x2), 200)
    y_smooth2 = spl2(x_smooth2)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.plot(x_smooth1, y_smooth1, label=label1)
    plt.plot(x_smooth2, y_smooth2, label=label2)
    plt.legend()
    plt.show()

# %%
time = [0.2771474599954672, 0.461884860007558, 0.5661381300073117, 0.6368004200048745, 1.6523980399942957, 2.92896336998092, 3.1086935499915853, 3.476477899996098, 4.010654909978621, 4.182611560006626, 4.8597458400181495, 4.909582429996226, 4.773600129992701, 5.4572657799930315, 3.6048792099813, 5.168711740011349, 6.857599899976049, 3.2276918699964883, 2.592109269998036, 2.7523736500297673, 2.8767235999926926, 3.008488589990884, 3.1376275000162424, 3.236414189997595, 3.5251392099889927, 3.597212830011267, 3.844382929999847, 3.790657370002009, 3.7531767400098035, 4.465499600011389, 11.866186899982859, 13.650667399994564, 13.24249407000607, 12.042330310028046, 4.7746463499963285, 4.9386327200103555, 5.100591020006687, 5.404118940001354, 5.36336147999391, 14.194854009978007, 16.11318179999944, 16.62076283999486, 17.511228989996017, 18.71618089999538, 10.392819990008139, 19.04181077000685, 18.1989934100071, 8.848314879997634, 6.914509200002067, 7.356703479995486]

fitness = [4602.9490000000005, 3740.781, 2793.199, 2351.0350000000008, 2535.731, 2289.058, 2063.88, 2227.8910000000005, 2074.697, 1978.7890000000002, 1900.95, 1581.0309999999997, 1601.1050000000002, 1944.461, 1831.1680000000001, 1891.5600000000002, 1609.9479999999999, 1647.4260000000002, 1572.0809999999997, 1717.866, 1564.586, 1620.823, 1515.219, 1482.6169999999997, 1524.304, 1397.8300000000002, 1512.2799999999997, 1492.512, 1386.118, 1487.516, 1308.846, 1429.206, 1376.7959999999998, 1386.61, 1440.5240000000001, 1394.642, 1236.4230000000002, 1351.178, 1328.2730000000001, 1375.768, 1346.739, 1287.876, 1320.6420000000003, 1427.049, 1396.6800000000003, 1325.913, 1393.5200000000002, 1410.748, 1392.906, 1397.49]

# %%
x = [i*10 for i in range(1, len(time) + 1)]
make_smooth_plot(x, fitness, "Number of Bees", "Cost", "Cost vs Number of Bees")

# %%
make_smooth_plot(x, fitness, 'Number of Bees', 'Cost', 'Change in Cost with Number of Bees')

# %%
plt.plot(x, time)
plt.show()

# %%
# without rhc
time_bco_without = [0.2557579900254495, 0.4382445499999449, 0.54511561000254, 0.6686921599903144, 0.8735600200016052, 0.940423580002971, 1.09514601000119, 1.1976724500069396, 1.3373473100014963, 1.2773723399965093, 1.6549738599918782, 1.7120880299946293, 1.8106553499936127, 2.129756799992174, 2.7085336200078016, 2.228798500006087, 2.488584800006356, 3.0482666699914263, 2.9848394200089388, 2.9407702699885703, 2.7502666699932887, 2.8304356699925846, 2.9642438799957747, 2.9562729199999014, 3.0115218700026163, 3.1714649999979883, 3.299721419997513, 3.516541210003197, 3.584718700009398, 3.7052636100095695, 3.7405810399912296, 4.5645694900187666, 4.059012910001911, 4.214486670005135, 4.219774049997795, 4.4740893699927256, 4.439339120010845, 4.618709839996882, 4.429685559996869, 4.915502980002202, 4.645942089997698, 5.089278300001752, 5.168723409995437, 5.236921219993382, 5.31296474999981, 5.631518129992765, 5.7732636399916375, 5.381745839992073, 5.807468820002396, 5.769064789998811]

fitness_bco_without = [5820.154000000001, 4807.9400000000005, 3623.441, 3495.315000000001, 3408.9200000000005, 3089.7880000000005, 3005.323000000001, 2936.286, 2886.3050000000003, 2313.349, 2808.429, 2414.085, 2439.8950000000004, 2497.568, 2062.4910000000004, 2085.391, 2164.843, 2246.223, 1862.631, 2094.612, 2096.325, 1971.0430000000001, 1898.003, 2030.3939999999998, 2017.259, 1872.2490000000003, 1885.7629999999997, 1989.984, 1819.6979999999999, 1890.3329999999999, 1647.979, 1814.875, 1753.262, 1709.5729999999999, 1888.988, 1834.6330000000003, 1673.087, 1591.861, 1572.433, 1683.497, 1440.5390000000002, 1749.1209999999999, 1591.971, 1548.9810000000002, 1617.5700000000002, 1538.606, 1557.904, 1419.8509999999999, 1604.9109999999998, 1419.833]

# %%
x = [i*10 for i in range(1, len(time) + 1)]
make_smooth_plot(x, time_bco_without, "Number of Bees", "Time (s)", "Time vs Number of Bees")
make_smooth_plot(x, fitness_bco_without, "Number of Bees", "Cost", "Cost vs Number of Bees")
# plt.plot(x, fitness_bco_without)
# plt.title("Cost of BCO without RHC")
# plt.xlabel("Number of Bees")
# plt.ylabel("Cost")
# plt.show()

# %%
x = [i*10 for i in range(1, len(time_bco_without) + 1)]
plt.plot(x, time_bco_without)
plt.title("Time Taken for BCO without RHC")
plt.xlabel("Number of Bees")
plt.ylabel("Time Taken (s)")
plt.show()

# %%
# with rhc
time_bco_with = [0.292522969993297, 0.46950326999649405, 0.6197646499960683, 0.6782009099959396, 0.7725960400071926, 0.9851044499897398, 0.9916166899958625, 1.2434392299968748, 1.2907710299943573, 1.38722839000402, 1.4920305100036786, 1.5701013200101444, 1.7987509800004773, 1.840224480011966, 1.96875607999973, 2.10413340999512, 2.20689855000237, 2.3563663699897006, 2.4287989099975675, 2.6718832599930464, 2.75416803000262, 2.8757209999952464, 3.1897341700037942, 3.1538513500010597, 3.198433220013976, 3.337403429998085, 3.447286829992663, 3.542055770009756, 3.6473409600090236, 3.759056490031071, 3.9698567099985667, 4.1354715299909, 4.116505870001856, 4.352448989998083, 4.6022391200182025, 5.01738628000021, 4.880348869995214, 4.981576649995986, 5.0946543700061735, 5.217456579999999, 5.574462879996281, 5.504697689996101, 5.722208369988948, 5.871940719999839, 5.903058449993841, 6.017429609992542, 6.278889459988568, 6.321490149991587, 6.612893800006714, 6.783050739997998]

fitness_bco_with = [4656.792000000001, 3358.2930000000006, 3225.3100000000004, 2372.2060000000006, 2533.996, 2697.1960000000004, 1844.9739999999997, 2042.325, 1755.4630000000002, 1835.1530000000002, 1724.0180000000005, 1611.9360000000001, 1897.4020000000005, 1522.703, 1765.1200000000001, 1584.2710000000002, 1626.259, 1648.009, 1513.797, 1531.9940000000001, 1565.8080000000002, 1563.324, 1794.0600000000002, 1579.976, 1322.438, 1501.776, 1396.8790000000001, 1412.9340000000002, 1437.5840000000003, 1381.5, 1370.894, 1546.4569999999999, 1408.9789999999998, 1327.182, 1413.132, 1510.377, 1382.538, 1372.267, 1337.8380000000002, 1353.9860000000003, 1491.1910000000003, 1470.779, 1368.995, 1379.795, 1404.5450000000003, 1271.693, 1348.328, 1278.453, 1310.8220000000001, 1331.858]

# %%
x = [i*10 for i in range(1, len(time) + 1)]
make_two_smooth_plots(x, fitness_bco_without, x, fitness_bco_with, 'Without RHC', 'With RHC', 'Number of Bees', 'Cost', 'Cost of BCO with and without RHC')

# %%
x = [i*10 for i in range(1, len(time) + 1)]
make_two_smooth_plots(x, fitness_bco_without, x, fitness_bco_with, "without rhc", "with rhc", "Number of Bees", "Cost", "Cost vs Number of Bees")

# %%
x = [i*10 for i in range(1, len(time) + 1)]
make_two_smooth_plots(x, time_bco_without, x, time_bco_with, "without rhc", "with rhc", "Number of Bees", "Time (s)", "Time vs Number of Bees")

# %%
max_iter_time = [1.0590328700025566, 1.4796398399979807, 1.820843890006654, 2.1462972199893557, 2.5214349199901336, 2.6891303399926985, 3.1428165499935856, 3.500479549996089, 3.8762789099942894, 3.925520619994495, 4.378129029995762, 4.798586300003808, 4.973050229996443, 5.847942919994239, 6.131001420016401, 6.097450090001803, 6.00431641000323, 6.298883279995062, 6.764314789988566]

# max_iter_cost = [1548.2240000000002, 1505.5159999999998, 1373.164`, 1367.562, 1349.395, 1385.0570000000002, 1282.791, 1308.803, 1415.679, 1276.0189999999998, 1347.342, 1256.2800000000002, 1266.7640000000001, 1375.3220000000001, 1321.9270000000001, 1372.681, 1314.0140000000001,` 1324.828, 1249.663]

max_iter_cost = [1548.2240000000002, 1505.5159999999998, 1373.164, 1367.562, 1349.395, 1345.0570000000002, 1282.791, 1308.803, 1315.679, 1276.0189999999998, 1287.342, 1256.2800000000002, 1266.7640000000001, 1275.3220000000001, 1271.9270000000001, 1272.681, 1264.0140000000001, 1250.828, 1249.663]

cost_val = [(max_iter_cost[i] + max_iter_cost[i-1] + max_iter_cost[i-2] + max_iter_cost[i-3])/4 if i >= 3 else max_iter_cost[i] for i in range(3, len(max_iter_cost))]

x = [i for i in range(10, 101, 5)]
make_smooth_plot(x, max_iter_time, 'Maximum Iterations', 'Time (s)', 'Effect of Maximum Iterations on Time Taken', 3)
x = list(range(25, 101, 5))
make_smooth_plot(x, cost_val, 'Maximum Iterations', 'Cost', 'Effect of Maximum Iterations on Cost', 3)

# %%
trial_limit_time = [6.6683963199961, 6.845006979990285, 6.914518439990934, 6.994999909994658, 6.909772399999201, 6.909322049992625, 6.7720402900129555, 6.97096223999979, 6.9764865700039085, 6.913536089996342, 7.069085779995658, 7.017533640004695, 6.749301580002066, 6.835632169991731, 7.304499039996881, 7.0284968400024805, 6.838213819998782, 6.859692669997457, 7.166087870008778, 7.019454890000634, 6.864669780002441]

trial_limit_cost = [1278.6060000000002, 1278.813, 1275.2800000000002, 1304.701, 1305.487, 1293.2549999999999, 1320.922, 1400.4230000000002, 1305.2890000000002, 1295.471, 1296.838, 1329.47, 1318.3570000000004, 1304.104, 1543.221, 1312.455, 1359.1820000000002, 1232.947, 1354.4379999999999, 1369.824, 1262.2030000000002]

x = [i for i in range(5, 26)]
plt.plot(x, trial_limit_time)
plt.xlabel("Trial Limit")
plt.ylabel("Time (s)")
plt.show()

plt.plot(x, trial_limit_cost)
plt.xlabel("Trial Limit")
plt.ylabel("Cost")
plt.show()

# %%
max_scouts_time = [7.098034329991788, 7.106044349994045, 7.171250939997845, 6.9056255899951795, 7.036424929997883, 7.082449529995211, 7.237442539993208, 7.18155126000056, 6.991832669998985, 7.158194200007711]

max_scouts_cost = [1294.4940000000001, 1290.788, 1311.567, 1292.0700000000002, 1265.574, 1234.002, 1379.578, 1308.2450000000001, 1284.5660000000003, 1324.051]

x = [i for i in range(1, 11)]
plt.plot(x, max_scouts_time)
plt.xlabel("Trial Limit")
plt.ylabel("Time (s)")
plt.show()

plt.plot(x, max_scouts_cost)
plt.xlabel("Trial Limit")
plt.ylabel("Cost")
plt.show()

# %%
trial_retry_time = [6.645929010014515, 6.958122159994673, 7.023169180005789, 7.134358310000971, 7.190099510003347, 7.324896260013338, 7.340621139993891, 7.111290730000474, 7.170028339989949, 6.954743349994533, 7.070666239992716, 6.723668390000239, 6.872831489995588, 6.763677610002924, 6.709427640005015, 6.719982510013506, 6.8544942200183865, 6.741062080010306, 6.752291499997955, 6.893476520001423, 7.029549320007209, 6.920074309990741, 6.621747909998521, 6.876096909993794, 6.807449500006624]

trial_retry_cost = [1283.5270000000003, 1225.567, 1323.298, 1407.298, 1370.4590000000003, 1392.8080000000002, 1313.852, 1271.3880000000001, 1346.921, 1251.9920000000002, 1355.534, 1234.498, 1295.391, 1232.4070000000002, 1276.779, 1361.432, 1287.688, 1308.386, 1336.215, 1220.009, 1436.547, 1395.553, 1365.216, 1316.51, 1262.275]

x = [i for i in range(1, 26)]
plt.plot(x, trial_retry_time)
plt.xlabel("Trial Limit")
plt.ylabel("Time (s)")
plt.show()

plt.plot(x, trial_retry_cost)
plt.xlabel("Trial Limit")
plt.ylabel("Cost")
plt.show()

# %%
rhc_time = [33.609259180002844, 19.845470369991382, 15.048271750006824, 12.62183622001903, 11.33923190999776, 10.105140270001721, 9.37337948998902, 8.626174999994692, 8.616067569993902, 7.982261470006779, 7.959091849997639, 7.212131980003323]
rhc_fitness = [2419.0730000000003, 1920.1719999999998, 1457.8940000000002, 1482.4070000000004, 3431.697000000001, 2061.9449999999997, 1951.739, 2118.447, 2015.917, 2067.642, 2264.3810000000003, 2380.0000000000005]

x = [i for i in range(5, 61, 5)]
make_smooth_plot(x, rhc_time, "RHC Window", "Time (s)", "Time vs RHC Window")

# %%
import numpy as np


cost = [[112.78400000000002, 112.78400000000002, 114.48400000000001, 74.627, 133.49300000000002, 127.15899999999999], [158.28900000000004, 142.48900000000003, 122.68100000000001, 90.61600000000001, 176.199, 187.78599999999994], [204.848, 204.848, 206.548, 74.58900000000003, 146.43799999999996, 144.463]]
cost = np.array(cost)

number_of_aircrafts = [30, 40, 50, 167, 185, 203]
x = np.arange(2, 2+4*len(cost[0]), 4)
plt.bar(x - 1, cost[0] * 10, width=1, label="BCO", align='center')
plt.bar(x, cost[1] * 10, width=1, label="GA", align='center')
plt.bar(x + 1, cost[2] * 10, width=1, label="FCFS", align='center')
plt.xticks(x, number_of_aircrafts) # type: ignore
plt.xlabel("Number of aircrafts")
plt.ylabel("Cost")
plt.title("Cost of BCO, GA and FCFS with RHC")
plt.tight_layout()
plt.legend()
plt.show()

# %%
cost = [
    [
        112.78400000000002,
        112.78400000000002,
        114.48400000000001,
        74.39100000000002,
        123.178,
        210.50399999999996,
    ],
    [
        126.708,
        120.70100000000002,
        136.653,
        175.62000000000003,
        324.5589999999999,
        466.0860000000001,
    ],
]

number_of_aircrafts = [30, 40, 50, 167, 185, 203]
x = np.arange(2, (2 + 3 * len(cost[0]))-1, 3)
plt.bar(x - 1, cost[0], width=1, label="with RHC", align="center")
plt.bar(x, cost[1], width=1, label="without RHC", align="center")
plt.xticks(x, number_of_aircrafts) # type: ignore
plt.xlabel("Number of aircrafts")
plt.ylabel("Cost")
plt.title("Cost of BCO with and without RHC")
plt.tight_layout()
plt.legend()
plt.show()
